# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math

# %% [markdown]
# ### Data
#
# * Join the tables for W01 and W02.
# * Select features from file and add colors.
# * Check number of members vs non members.
# * Split into training, validation and testing samples.

# %%
df1 = pd.read_csv('../../DATA/HSC-unWISE-W01.csv')
df2 = pd.read_csv('../../DATA/HSC-unWISE-W02.csv')
df = pd.concat([df1,df2], axis = 'rows')
del df1,df2

# %%
df_cl = pd.read_table('../../DATA/clusters.dat', sep='\s+', usecols=[0,3,4,5,9,11,12], names=['id_cl','ra_cl','dec_cl','phot_z_cl', 'r500_cl','mass_cl','n500_cl'])
# df has a column 'id_cl_near', with the ids of the nearest cluster. Select galaxies near clusters in a z and n500 range...

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.kdeplot(df_cl.phot_z_cl, fill = True, alpha = 0.7)
plt.grid()
plt.subplot(1,2,2)
sns.kdeplot(df_cl.n500_cl, fill = True, alpha = 0.7)
plt.xlim(0,75)
plt.grid()

df_cl = df_cl[
    (df_cl.n500_cl >= 15) &
    (df_cl.phot_z_cl <= 0.7)
]

# the id_cl_near are in a list as a string (because some galaxies are near two or more clusters). Evaluate the strings to get the lists.
# df = df[df['id_cl_near'].isin(df_cl.id_cl)]
df['id_cl_near'] = [eval(s) for s in df['id_cl_near']]
df = df[[any([id in df_cl['id_cl'].values for id in gal.id_cl_near]) for _,gal in df.iterrows()]]
# # del df_cl

# %%
with open('../../DATA/old_features.txt') as file:
    features = file.read().splitlines()
labels = 'member'

n_mem = df[df.member == 1].shape[0]
n_no = df[df.member == 0].shape[0]
n = df.shape[0]
print ('Members: {} ({:.2f}%)'.format(n_mem, n_mem/n*100))
print ('Non members: {} ({:.2f}%)'.format(n_no, n_no/n*100))
del n,n_mem,n_no

from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.3, stratify = df[labels])
val, test = train_test_split(test, test_size = 0.3, stratify = test[labels])
print ('Training: {} members, {} non members'.format(train[train.member == 1].shape[0], train[train.member == 0].shape[0]))
print ('Validation: {} members, {} non members'.format(val[val.member == 1].shape[0], val[val.member == 0].shape[0]))
print ('Testing: {} members, {} non members'.format(test[test.member == 1].shape[0], test[test.member == 0].shape[0]))
# Out:
# Members: 19737 (28.32%)
# Non members: 49959 (71.68%)
# Training: 13816 members, 34971 non members
# Validation: 4145 members, 10491 non members
# Testing: 1776 members, 4497 non members

# %% [markdown]
# ### Model

# %%
callbacks = [
    # tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
    tf.keras.callbacks.CSVLogger(filename = 'saved_models/history_4.csv'),
    tf.keras.callbacks.ModelCheckpoint(filepath = 'saved_models/model_4.h5', monitor = 'val_loss',  save_best_only = True),
    # tf.keras.callbacks.TensorBoard()
]

norm = tf.keras.layers.Normalization(input_shape=(len(features),))
norm.adapt(data = train[features])

# %%
from sklearn.utils.class_weight import compute_class_weight
wei =  compute_class_weight(class_weight = 'balanced', classes = np.unique(df[labels]), y = df[labels])
weights = {}
for w,l in zip(wei,np.unique(df[labels])):
    weights[l] = w

del wei
print (weights)
# Out:
# {0: 0.6975319762205008, 1: 1.7656178750569995}

# %%
model = tf.keras.Sequential([
    norm,
    tf.keras.layers.Dense(64, activation=tf.keras.activations.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation=tf.keras.activations.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer = tf.keras.optimizers.experimental.AdamW(),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics=[]
)
# tf.keras.metrics.BinaryAccuracy(name = 'accuracy'), tf.keras.metrics.Precision(name = 'precision'), tf.keras.metrics.Recall(name = 'recall')

# %%
model.fit(
    x = train[features].values, 
    y = train[labels].values,
    verbose = 1, 
    callbacks = callbacks,
    validation_data = (val[features].values, val[labels].values), 
    epochs = 60,
    batch_size = 4096,
    class_weight = weights
)
# Out:
# Epoch 1/60
# 10/12 [========================>.....] - ETA: 0s - loss: 0.6200WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 2s 48ms/step - loss: 0.6126 - val_loss: 0.5564
# Epoch 2/60
#  9/12 [=====================>........] - ETA: 0s - loss: 0.5741WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 22ms/step - loss: 0.5727 - val_loss: 0.5554
# Epoch 3/60
# 12/12 [==============================] - ETA: 0s - loss: 0.5546WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 24ms/step - loss: 0.5546 - val_loss: 0.5408
# Epoch 4/60
# 11/12 [==========================>...] - ETA: 0s - loss: 0.5425WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 23ms/step - loss: 0.5424 - val_loss: 0.5270
# Epoch 5/60
# 11/12 [==========================>...] - ETA: 0s - loss: 0.5324WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 24ms/step - loss: 0.5321 - val_loss: 0.5172
# Epoch 6/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.5241 - val_loss: 0.5172
# Epoch 7/60
#  9/12 [=====================>........] - ETA: 0s - loss: 0.5208WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 22ms/step - loss: 0.5205 - val_loss: 0.5021
# Epoch 8/60
# 12/12 [==============================] - 0s 23ms/step - loss: 0.5161 - val_loss: 0.5069
# Epoch 9/60
# 12/12 [==============================] - 0s 19ms/step - loss: 0.5128 - val_loss: 0.5046
# Epoch 10/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.5097 - val_loss: 0.5036
# Epoch 11/60
# 12/12 [==============================] - ETA: 0s - loss: 0.5084WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 23ms/step - loss: 0.5084 - val_loss: 0.4984
# Epoch 12/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.5066 - val_loss: 0.5017
# Epoch 13/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.5050 - val_loss: 0.4988
# Epoch 14/60
# 12/12 [==============================] - ETA: 0s - loss: 0.5036WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 24ms/step - loss: 0.5036 - val_loss: 0.4962
# Epoch 15/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.5030 - val_loss: 0.5012
# Epoch 16/60
# 12/12 [==============================] - 0s 30ms/step - loss: 0.5023 - val_loss: 0.5007
# Epoch 17/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.5000 - val_loss: 0.4974
# Epoch 18/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4971 - val_loss: 0.4987
# Epoch 19/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4978 - val_loss: 0.4980
# Epoch 20/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4971 - val_loss: 0.4966
# Epoch 21/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4960 - val_loss: 0.4986
# Epoch 22/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4958 - val_loss: 0.5024
# Epoch 23/60
# 10/12 [========================>.....] - ETA: 0s - loss: 0.4935WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 20ms/step - loss: 0.4935 - val_loss: 0.4898
# Epoch 24/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4941 - val_loss: 0.5008
# Epoch 25/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4931 - val_loss: 0.4959
# Epoch 26/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4927 - val_loss: 0.4920
# Epoch 27/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4916 - val_loss: 0.4962
# Epoch 28/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4904 - val_loss: 0.4957
# Epoch 29/60
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4897 - val_loss: 0.4935
# Epoch 30/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4894 - val_loss: 0.4923
# Epoch 31/60
# 12/12 [==============================] - 0s 19ms/step - loss: 0.4878 - val_loss: 0.4974
# Epoch 32/60
# 12/12 [==============================] - ETA: 0s - loss: 0.4877WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4877 - val_loss: 0.4886
# Epoch 33/60
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4870 - val_loss: 0.4919
# Epoch 34/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4852 - val_loss: 0.4911
# Epoch 35/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4843 - val_loss: 0.4901
# Epoch 36/60
# 10/12 [========================>.....] - ETA: 0s - loss: 0.4830WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 27ms/step - loss: 0.4852 - val_loss: 0.4879
# Epoch 37/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4840 - val_loss: 0.4911
# Epoch 38/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4858 - val_loss: 0.4966
# Epoch 39/60
#  8/12 [===================>..........] - ETA: 0s - loss: 0.4841WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 29ms/step - loss: 0.4835 - val_loss: 0.4876
# Epoch 40/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4830 - val_loss: 0.4931
# Epoch 41/60
# 12/12 [==============================] - 0s 20ms/step - loss: 0.4818 - val_loss: 0.4880
# Epoch 42/60
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4814 - val_loss: 0.4932
# Epoch 43/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4815 - val_loss: 0.4877
# Epoch 44/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4812 - val_loss: 0.4884
# Epoch 45/60
# 12/12 [==============================] - ETA: 0s - loss: 0.4800WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4800 - val_loss: 0.4857
# Epoch 46/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4808 - val_loss: 0.4917
# Epoch 47/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4799 - val_loss: 0.4864
# Epoch 48/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4778 - val_loss: 0.4908
# Epoch 49/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4790 - val_loss: 0.4907
# Epoch 50/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4775 - val_loss: 0.4876
# Epoch 51/60
# 11/12 [==========================>...] - ETA: 0s - loss: 0.4773WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4785 - val_loss: 0.4831
# Epoch 52/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4772 - val_loss: 0.4911
# Epoch 53/60
# 12/12 [==============================] - ETA: 0s - loss: 0.4769WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 24ms/step - loss: 0.4769 - val_loss: 0.4831
# Epoch 54/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4760 - val_loss: 0.4914
# Epoch 55/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4754 - val_loss: 0.4838
# Epoch 56/60
#  9/12 [=====================>........] - ETA: 0s - loss: 0.4752WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 12/12 [==============================] - 0s 23ms/step - loss: 0.4744 - val_loss: 0.4792
# Epoch 57/60
# 12/12 [==============================] - 0s 25ms/step - loss: 0.4752 - val_loss: 0.4904
# Epoch 58/60
# 12/12 [==============================] - 0s 21ms/step - loss: 0.4757 - val_loss: 0.4855
# Epoch 59/60
# 12/12 [==============================] - 0s 22ms/step - loss: 0.4736 - val_loss: 0.4852
# Epoch 60/60
# 12/12 [==============================] - 0s 18ms/step - loss: 0.4732 - val_loss: 0.4839

# %%
# load best model and training history
model = tf.keras.models.load_model('saved_models/model_4.h5')
history = pd.read_csv('saved_models/history_4.csv')
# Out:
# WARNING:tensorflow:Loading model from HDF5 will not restore the optimizer's weights, since the optimizer is an instance of `optimizer_experimental.Optimizer`

# %% [markdown]
# ### Tests
#
# * Training and validation loss plot
# * Confusion matrix plot
# * ROC curve plot
# * Loss on test sample
# * ROC & precision-recall AUC
# * Precision, recall, F1...

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, classification_report

pred = model.predict(test[features], verbose = 0)
pred_classes = np.round(pred, decimals = 0)

test_loss = model.evaluate(test[features], test[labels], verbose=0)
fpr, tpr, thresholds_roc = roc_curve(test[labels], pred, pos_label=1)
precision, recall, thresholds_pr = precision_recall_curve(test[labels], pred, pos_label= 1)

# def model_write(string):
#     file.write(string + '\n')

# with open('report.txt', mode='x') as file:
#     model.summary(print_fn= model_write)
#     file.write('\n\n')
#     file.write('Optimizer: {} \n'.format(model.optimizer))
#     file.write('Loss function: {} \n'.format(model.loss))
#     file.write('Notes: \n')
#     file.write('-'*70 + '\n')
#     file.write('Loss on test dataset: {:.4g} \n'.format(test_loss))
#     file.write('AUC: {}\n'.format(auc(fpr, tpr)))
#     file.write('-'*70 + '\n')
#     file.write(classification_report(test[labels],pred_classes))

print('Loss on test dataset: {:.4g} \n'.format(test_loss))
print('ROC AUC: {}\n'.format(auc(fpr, tpr)))
print('Precision-recall AUC: {}\n'.format(auc(recall, precision)))
print('-'*70 + '\n')
print(classification_report(test[labels],pred_classes))
# Out:
# Loss on test dataset: 0.4744
#
# ROC AUC: 0.8461076152870682
#
# Precision-recall AUC: 0.6388121900321015
#
# ----------------------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.80      4497
#            1       0.53      0.82      0.65      1776
#
#     accuracy                           0.75      6273
#    macro avg       0.72      0.77      0.72      6273
# weighted avg       0.80      0.75      0.76      6273

# %%
from sklearn.metrics import confusion_matrix
plt.figure(figsize=(10,10))

# Loss during training
plt.subplot(2, 2, 1)
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend()

# Confusion matrix
plt.subplot(2, 2, 2)
conf_m = confusion_matrix(test[labels], pred_classes)
df_conf_m = pd.DataFrame(conf_m, index=[0,1], columns=[0,1])
sns.heatmap(df_conf_m, cmap=sns.color_palette('light:teal', as_cmap=True), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')

# ROC Curve
plt.subplot(2, 2, 3)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.grid()

# Precision-recall curve
plt.subplot(2, 2, 4)
plt.plot(recall, precision)
plt.plot([0, 1], [len (test[test.member == 1])/len(test), len (test[test.member == 1])/len(test)] , color='gray', linestyle='--')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid()
plt.xlim([0,1])
plt.ylim([0,1])

# plt.savefig('fig.png', dpi=150, bbox_inches= 'tight')
plt.show()

# %% [markdown]
# ### Perfomance vs Features

# %%
feat_test = ['W1', 'i_cmodel_mag', 'r_cmodel_mag', 'i_cmodel_magsigma', 'i_kronflux_radius', 'i_sdssshape_shape11', 'ri']

# check distributions...
plt.figure(figsize=(18, 3*math.ceil(len(feat_test)/5)))
for i,f in enumerate(feat_test):
    plt.subplot(math.ceil(len(feat_test)/5), 5, i+1)
    sns.kdeplot(df[f], fill = True, alpha = 0.5)
    plt.grid()
plt.show()
plt.close()

# %%
def cut_tests(f, feat_cuts, color):
    feat_cond = []
    for i in range(len(feat_cuts) - 1):
        feat_cond.append(
            (test[f] >= feat_cuts[i]) & (test[f] <= feat_cuts[i+1])
        )

    plt.figure(figsize=(18,4*math.ceil(len(feat_test)/4)))
    for i,c in enumerate(feat_cond):
        # Confusion matrix
        plt.subplot(math.ceil(len(feat_test)/4), 4, i+1)
        conf_m = confusion_matrix(test[c][labels], pred_classes[c])
        df_conf_m = pd.DataFrame(conf_m, index=[0,1], columns=[0,1])
        sns.heatmap(df_conf_m, cmap=sns.color_palette(f'light:{color}', as_cmap=True), annot=True, fmt='d')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'{f} in ({feat_cuts[i]}, {feat_cuts[i+1]})')

    plt.figure(figsize=(18,4*math.ceil(len(feat_test)/4)))
    for i,c in enumerate(feat_cond):
        # ROC Curve
        plt.subplot(math.ceil(len(feat_test)/4), 4, i+1)
        plt.title(f'{f} in ({feat_cuts[i]}, {feat_cuts[i+1]})')
        fpr_1, tpr_1, _ = roc_curve(test[c][labels], pred[c], pos_label=1)
        plt.plot(fpr_1, tpr_1, c = color)
        plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.grid()

# %%
cut_tests('W1', feat_cuts = [15,18,20,24], color = 'teal')

# %%
cut_tests('i_cmodel_mag', feat_cuts = [15,20,23,26], color = 'chocolate')

# %%
cut_tests('i_cmodel_magsigma', feat_cuts = [0,0.02,0.05,0.3], color = 'indigo')

# %%
cut_tests('ri', feat_cuts = [-2,0.5,1,3], color = 'tomato')

# %% [markdown]
# ### Thresholds

# %%
# get predictions with different thresholds

pred_c_thres = []
thresholds = [0.30,0.45,0.5,0.55,0.60]

for t in thresholds:
    pred_c_thres.append(
        [math.floor(p[0]) if p[0] < t else math.ceil(p[0]) for p in pred]
    )
    
# plot conf matrix for each
plt.figure(figsize=(15,10))

for i,(p,t) in enumerate(zip(pred_c_thres,thresholds)):
    plt.subplot(2, 3, i+1)
    plt.title(t)
    c = confusion_matrix(test[labels], p)
    c = pd.DataFrame(c, index=[0,1], columns=[0,1])
    sns.heatmap(c, cmap=sns.color_palette('light:mediumvioletred', as_cmap=True), annot=True, fmt='d')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    
# plt.savefig('fig.png', dpi=150, bbox_inches= 'tight')
plt.show()

# %%
# With G-Mean
# calculate the g-mean for each threshold
gmeans = (tpr * (1-fpr))**(1/2)

# locate the index of the largest g-mean
max_gmeans = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds_roc[max_gmeans], gmeans[max_gmeans]))

# ROC Curve
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, marker = '.')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.plot(fpr[max_gmeans], tpr[max_gmeans], marker='o', color='black', label='Best')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.grid()

# Conf matrix
pred_gmeans = [math.floor(p[0]) if p[0] < thresholds_roc[max_gmeans] else math.ceil(p[0]) for p in pred]
plt.subplot(1, 2, 2)
c = confusion_matrix(test[labels], pred_gmeans)
c = pd.DataFrame(c, index=[0,1], columns=[0,1])
sns.heatmap(c, cmap=sns.color_palette('light:mediumvioletred', as_cmap=True), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')

# %%
# with f-score
fscore = (2 * precision * recall) / (precision + recall)
max_f = np.argmax(fscore)
print('Best Threshold=%f, F-Score=%.3f' % (thresholds_pr[max_f], fscore[max_f]))

plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(recall, precision)
plt.plot(recall[max_f], precision[max_f], marker='o', color='black', label='Best')
plt.plot([0, 1], [len (test[test.member == 1])/len(test), len (test[test.member == 1])/len(test)] , color='gray', linestyle='--')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid()
plt.xlim([0,1])
plt.ylim([0,1])

# Conf matrix
pred_f = [math.floor(p[0]) if p[0] < thresholds_pr[max_f] else math.ceil(p[0]) for p in pred]
plt.subplot(1, 2, 2)
c = confusion_matrix(test[labels], pred_f)
c = pd.DataFrame(c, index=[0,1], columns=[0,1])
sns.heatmap(c, cmap=sns.color_palette('light:mediumvioletred', as_cmap=True), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
